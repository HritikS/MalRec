# %%
from fastai import *
from fastai.tabular import *

# %%
path = '/home/hritik/Documents/BirdVision'

# %%
df = pd.read_csv('data.csv', sep = '|')
df = df.drop(['Name', 'md5'], axis=1)
df.head()
# Out:
#    Machine  SizeOfOptionalHeader  Characteristics  MajorLinkerVersion  \
# 0      332                   224              258                   9
# 1      332                   224             3330                   9
# 2      332                   224             3330                   9
# 3      332                   224              258                   9
# 4      332                   224              258                   9
#
#    MinorLinkerVersion  SizeOfCode  SizeOfInitializedData  \
# 0                   0      361984                 115712
# 1                   0      130560                  19968
# 2                   0      517120                 621568
# 3                   0      585728                 369152
# 4                   0      294912                 247296
#
#    SizeOfUninitializedData  AddressOfEntryPoint  BaseOfCode  ...  ResourcesNb  \
# 0                        0                 6135        4096  ...            4
# 1                        0                81778        4096  ...            2
# 2                        0               350896        4096  ...           11
# 3                        0               451258        4096  ...           10
# 4                        0               217381        4096  ...            2
#
#    ResourcesMeanEntropy  ResourcesMinEntropy  ResourcesMaxEntropy  \
# 0              3.262823             2.568844             3.537939
# 1              4.250461             3.420744             5.080177
# 2              4.426324             2.846449             5.271813
# 3              4.364291             2.669314             6.400720
# 4              4.306100             3.421598             5.190603
#
#    ResourcesMeanSize  ResourcesMinSize  ResourcesMaxSize  \
# 0        8797.000000               216             18032
# 1         837.000000               518              1156
# 2       31102.272727               104            270376
# 3        1457.000000                90              4264
# 4        1074.500000               849              1300
#
#    LoadConfigurationSize  VersionInformationSize  legitimate
# 0                      0                      16           1
# 1                     72                      18           1
# 2                     72                      18           1
# 3                     72                      18           1
# 4                     72                      18           1
#
# [5 rows x 55 columns]

# %%
procs = [Normalize]

# %%
valid_idx = range(len(df) - 27609, len(df))

# %%
dep_var = 'legitimate'

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs)
data
# Out:
# TabularDataBunch;
#
# Train: LabelList (110438 items)
# x: TabularList
# SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2823; SizeOfCode 0.0147; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0454; MinorImageVersion -0.0632; BaseOfData 0.0865; ResourcesMinEntropy 0.1136; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0113; SectionsMeanEntropy 1.0742; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion -0.0267; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0144; VersionInformationSize 0.4896; ImageBase -0.0060; ResourcesNb -0.1322; Machine -0.4100; DllCharacteristics -1.2382; MajorOperatingSystemVersion -0.0472; ImportsNb -0.8733; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -1.1684; LoaderFlags -0.0030; SectionsMinEntropy 0.7727; Characteristics -0.5712; SectionsMeanRawsize -0.0171; SectionsMinVirtualsize -0.0593; SectionsMinRawsize -0.0555; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0062; ExportNb -0.1042; ResourcesMinSize -0.0031; MinorSubsystemVersion -0.6598; ResourcesMeanSize -0.0061; MajorLinkerVersion 0.0926; ResourcesMeanEntropy -0.6487; SizeOfOptionalHeader -0.4094; Subsystem 27.7328; SectionsMaxEntropy 0.3409; MajorImageVersion -0.0644; SizeOfImage 0.0322; BaseOfCode -0.0089; SizeOfInitializedData -0.0151; SectionsNb 1.5882; ResourcesMaxSize -0.0104; MajorSubsystemVersion -5.7324; SizeOfStackCommit -0.0783; ImportsNbDLL -1.2414; ,SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2828; SizeOfCode -0.0213; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0256; MinorImageVersion -0.0632; BaseOfData -0.0411; ResourcesMinEntropy 1.1262; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0177; SectionsMeanEntropy 0.2384; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion 0.0066; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0337; VersionInformationSize 0.7935; ImageBase -0.0060; ResourcesNb -0.1455; Machine -0.4100; DllCharacteristics 0.7768; MajorOperatingSystemVersion -0.0021; ImportsNb 0.4950; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -0.2111; LoaderFlags -0.0030; SectionsMinEntropy 0.0892; Characteristics -0.1792; SectionsMeanRawsize -0.0202; SectionsMinVirtualsize -0.0569; SectionsMinRawsize -0.0529; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0360; ExportNb -0.1042; ResourcesMinSize -0.0030; MinorSubsystemVersion 0.1746; ResourcesMeanSize -0.0070; MajorLinkerVersion 0.0926; ResourcesMeanEntropy 0.2647; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; SectionsMaxEntropy -0.2636; MajorImageVersion -0.0644; SizeOfImage -0.0957; BaseOfCode -0.0089; SizeOfInitializedData -0.0192; SectionsNb -0.4805; ResourcesMaxSize -0.0112; MajorSubsystemVersion 0.1439; SizeOfStackCommit -0.0783; ImportsNbDLL 0.3406; ,SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2811; SizeOfCode 0.0388; SizeOfHeaders -0.0569; AddressOfEntryPoint 0.0451; MinorImageVersion -0.0632; BaseOfData 0.3305; ResourcesMinEntropy 0.4436; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0049; SectionsMeanEntropy 1.6536; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal 0.4140; SectionAlignment -0.0057; MinorOperatingSystemVersion 0.0066; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize 0.0195; VersionInformationSize 0.7935; ImageBase -0.0060; ResourcesNb -0.0860; Machine -0.4100; DllCharacteristics 0.7607; MajorOperatingSystemVersion -0.0021; ImportsNb 0.9032; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -0.0922; LoaderFlags -0.0030; SectionsMinEntropy 1.4805; Characteristics -0.1792; SectionsMeanRawsize 0.0102; SectionsMinVirtualsize -0.0074; SectionsMinRawsize -0.0037; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0087; ExportNb -0.1007; ResourcesMinSize -0.0031; MinorSubsystemVersion 0.1746; ResourcesMeanSize -0.0035; MajorLinkerVersion 0.0926; ResourcesMeanEntropy 0.4274; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; SectionsMaxEnt ...
# y: CategoryList
# 1,1,1,1,1
# Path: /home/hritik/Documents/BirdVision;
#
# Valid: LabelList (27609 items)
# x: TabularList
# SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2822; SizeOfCode -0.0231; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0313; MinorImageVersion -0.0632; BaseOfData -0.0525; ResourcesMinEntropy -0.0176; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0105; SectionsMeanEntropy 0.9780; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion 0.0066; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0193; VersionInformationSize 0.1858; ImageBase -0.0060; ResourcesNb -0.0002; Machine -0.4100; DllCharacteristics 0.7768; MajorOperatingSystemVersion -0.0021; ImportsNb -0.0266; MinorLinkerVersion -0.3137; ResourcesMaxEntropy 1.5952; LoaderFlags -0.0030; SectionsMinEntropy 1.0956; Characteristics -0.5712; SectionsMeanRawsize -0.0116; SectionsMinVirtualsize -0.0378; SectionsMinRawsize -0.0348; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0207; ExportNb -0.1042; ResourcesMinSize -0.0031; MinorSubsystemVersion 0.1746; ResourcesMeanSize -0.0054; MajorLinkerVersion 0.3460; ResourcesMeanEntropy 2.7263; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; SectionsMaxEntropy 1.0261; MajorImageVersion -0.0644; SizeOfImage -0.0413; BaseOfCode -0.0089; SizeOfInitializedData -0.0032; SectionsNb 0.0367; ResourcesMaxSize -0.0102; MajorSubsystemVersion 0.1439; SizeOfStackCommit -0.0783; ImportsNbDLL 0.3406; ,SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2831; SizeOfCode -0.0308; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0283; MinorImageVersion -0.0632; BaseOfData -0.0799; ResourcesMinEntropy -2.9398; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0197; SectionsMeanEntropy 0.1096; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion -0.0267; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0352; VersionInformationSize -1.9411; ImageBase -0.0060; ResourcesNb -0.1587; Machine -0.4100; DllCharacteristics 0.7728; MajorOperatingSystemVersion -0.0111; ImportsNb 3.6549; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -3.3643; LoaderFlags -0.0030; SectionsMinEntropy -0.4119; Characteristics -0.5710; SectionsMeanRawsize -0.0210; SectionsMinVirtualsize -0.0507; SectionsMinRawsize -0.0568; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0403; ExportNb -0.1042; ResourcesMinSize -0.0031; MinorSubsystemVersion -0.6598; ResourcesMeanSize -0.0071; MajorLinkerVersion 0.0926; ResourcesMeanEntropy -3.6662; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; SectionsMaxEntropy 0.1065; MajorImageVersion -0.0636; SizeOfImage -0.1041; BaseOfCode -0.0089; SizeOfInitializedData -0.0191; SectionsNb -0.9977; ResourcesMaxSize -0.0112; MajorSubsystemVersion -1.3252; SizeOfStackCommit -0.0783; ImportsNbDLL -0.1114; ,SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2821; SizeOfCode -0.0229; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0309; MinorImageVersion -0.0632; BaseOfData -0.0503; ResourcesMinEntropy -0.0176; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0111; SectionsMeanEntropy 0.9711; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion 0.0066; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0196; VersionInformationSize 0.3377; ImageBase -0.0060; ResourcesNb -0.1190; Machine -0.4100; DllCharacteristics 0.7768; MajorOperatingSystemVersion -0.0021; ImportsNb -0.2005; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -0.0638; LoaderFlags -0.0030; SectionsMinEntropy 1.0732; Characteristics -0.5712; SectionsMeanRawsize -0.0118; SectionsMinVirtualsize -0.0378; SectionsMinRawsize -0.0335; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0212; ExportNb -0.1042; ResourcesMinSize -0.0031; MinorSubsystemVersion 0.1746; ResourcesMeanSize -0.0068; MajorLinkerVersion 0.3460; ResourcesMeanEntropy -0.1925; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; S ...
# y: CategoryList
# 0,0,0,0,0
# Path: /home/hritik/Documents/BirdVision;
#
# Test: None

# %%
learn = tabular_learner(data, layers=[200, 100], metrics=accuracy)
learn
# Out:
# Learner(data=TabularDataBunch;
#
# Train: LabelList (110438 items)
# x: TabularList
# SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2823; SizeOfCode 0.0147; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0454; MinorImageVersion -0.0632; BaseOfData 0.0865; ResourcesMinEntropy 0.1136; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0113; SectionsMeanEntropy 1.0742; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion -0.0267; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0144; VersionInformationSize 0.4896; ImageBase -0.0060; ResourcesNb -0.1322; Machine -0.4100; DllCharacteristics -1.2382; MajorOperatingSystemVersion -0.0472; ImportsNb -0.8733; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -1.1684; LoaderFlags -0.0030; SectionsMinEntropy 0.7727; Characteristics -0.5712; SectionsMeanRawsize -0.0171; SectionsMinVirtualsize -0.0593; SectionsMinRawsize -0.0555; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0062; ExportNb -0.1042; ResourcesMinSize -0.0031; MinorSubsystemVersion -0.6598; ResourcesMeanSize -0.0061; MajorLinkerVersion 0.0926; ResourcesMeanEntropy -0.6487; SizeOfOptionalHeader -0.4094; Subsystem 27.7328; SectionsMaxEntropy 0.3409; MajorImageVersion -0.0644; SizeOfImage 0.0322; BaseOfCode -0.0089; SizeOfInitializedData -0.0151; SectionsNb 1.5882; ResourcesMaxSize -0.0104; MajorSubsystemVersion -5.7324; SizeOfStackCommit -0.0783; ImportsNbDLL -1.2414; ,SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2828; SizeOfCode -0.0213; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0256; MinorImageVersion -0.0632; BaseOfData -0.0411; ResourcesMinEntropy 1.1262; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0177; SectionsMeanEntropy 0.2384; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion 0.0066; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0337; VersionInformationSize 0.7935; ImageBase -0.0060; ResourcesNb -0.1455; Machine -0.4100; DllCharacteristics 0.7768; MajorOperatingSystemVersion -0.0021; ImportsNb 0.4950; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -0.2111; LoaderFlags -0.0030; SectionsMinEntropy 0.0892; Characteristics -0.1792; SectionsMeanRawsize -0.0202; SectionsMinVirtualsize -0.0569; SectionsMinRawsize -0.0529; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0360; ExportNb -0.1042; ResourcesMinSize -0.0030; MinorSubsystemVersion 0.1746; ResourcesMeanSize -0.0070; MajorLinkerVersion 0.0926; ResourcesMeanEntropy 0.2647; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; SectionsMaxEntropy -0.2636; MajorImageVersion -0.0644; SizeOfImage -0.0957; BaseOfCode -0.0089; SizeOfInitializedData -0.0192; SectionsNb -0.4805; ResourcesMaxSize -0.0112; MajorSubsystemVersion 0.1439; SizeOfStackCommit -0.0783; ImportsNbDLL 0.3406; ,SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2811; SizeOfCode 0.0388; SizeOfHeaders -0.0569; AddressOfEntryPoint 0.0451; MinorImageVersion -0.0632; BaseOfData 0.3305; ResourcesMinEntropy 0.4436; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0049; SectionsMeanEntropy 1.6536; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal 0.4140; SectionAlignment -0.0057; MinorOperatingSystemVersion 0.0066; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize 0.0195; VersionInformationSize 0.7935; ImageBase -0.0060; ResourcesNb -0.0860; Machine -0.4100; DllCharacteristics 0.7607; MajorOperatingSystemVersion -0.0021; ImportsNb 0.9032; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -0.0922; LoaderFlags -0.0030; SectionsMinEntropy 1.4805; Characteristics -0.1792; SectionsMeanRawsize 0.0102; SectionsMinVirtualsize -0.0074; SectionsMinRawsize -0.0037; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0087; ExportNb -0.1007; ResourcesMinSize -0.0031; MinorSubsystemVersion 0.1746; ResourcesMeanSize -0.0035; MajorLinkerVersion 0.0926; ResourcesMeanEntropy 0.4274; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; SectionsMaxEnt ...
# y: CategoryList
# 1,1,1,1,1
# Path: /home/hritik/Documents/BirdVision;
#
# Valid: LabelList (27609 items)
# x: TabularList
# SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2822; SizeOfCode -0.0231; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0313; MinorImageVersion -0.0632; BaseOfData -0.0525; ResourcesMinEntropy -0.0176; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0105; SectionsMeanEntropy 0.9780; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion 0.0066; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0193; VersionInformationSize 0.1858; ImageBase -0.0060; ResourcesNb -0.0002; Machine -0.4100; DllCharacteristics 0.7768; MajorOperatingSystemVersion -0.0021; ImportsNb -0.0266; MinorLinkerVersion -0.3137; ResourcesMaxEntropy 1.5952; LoaderFlags -0.0030; SectionsMinEntropy 1.0956; Characteristics -0.5712; SectionsMeanRawsize -0.0116; SectionsMinVirtualsize -0.0378; SectionsMinRawsize -0.0348; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0207; ExportNb -0.1042; ResourcesMinSize -0.0031; MinorSubsystemVersion 0.1746; ResourcesMeanSize -0.0054; MajorLinkerVersion 0.3460; ResourcesMeanEntropy 2.7263; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; SectionsMaxEntropy 1.0261; MajorImageVersion -0.0644; SizeOfImage -0.0413; BaseOfCode -0.0089; SizeOfInitializedData -0.0032; SectionsNb 0.0367; ResourcesMaxSize -0.0102; MajorSubsystemVersion 0.1439; SizeOfStackCommit -0.0783; ImportsNbDLL 0.3406; ,SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2831; SizeOfCode -0.0308; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0283; MinorImageVersion -0.0632; BaseOfData -0.0799; ResourcesMinEntropy -2.9398; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0197; SectionsMeanEntropy 0.1096; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion -0.0267; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0352; VersionInformationSize -1.9411; ImageBase -0.0060; ResourcesNb -0.1587; Machine -0.4100; DllCharacteristics 0.7728; MajorOperatingSystemVersion -0.0111; ImportsNb 3.6549; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -3.3643; LoaderFlags -0.0030; SectionsMinEntropy -0.4119; Characteristics -0.5710; SectionsMeanRawsize -0.0210; SectionsMinVirtualsize -0.0507; SectionsMinRawsize -0.0568; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0403; ExportNb -0.1042; ResourcesMinSize -0.0031; MinorSubsystemVersion -0.6598; ResourcesMeanSize -0.0071; MajorLinkerVersion 0.0926; ResourcesMeanEntropy -3.6662; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; SectionsMaxEntropy 0.1065; MajorImageVersion -0.0636; SizeOfImage -0.1041; BaseOfCode -0.0089; SizeOfInitializedData -0.0191; SectionsNb -0.9977; ResourcesMaxSize -0.0112; MajorSubsystemVersion -1.3252; SizeOfStackCommit -0.0783; ImportsNbDLL -0.1114; ,SizeOfHeapReserve 0.1130; NumberOfRvaAndSizes -0.0041; CheckSum -0.2821; SizeOfCode -0.0229; SizeOfHeaders -0.0569; AddressOfEntryPoint -0.0309; MinorImageVersion -0.0632; BaseOfData -0.0503; ResourcesMinEntropy -0.0176; SizeOfStackReserve 0.3010; SectionMaxRawsize -0.0111; SectionsMeanEntropy 0.9711; FileAlignment -0.1474; SizeOfUninitializedData -0.0771; ImportsNbOrdinal -0.1318; SectionAlignment -0.0057; MinorOperatingSystemVersion 0.0066; SizeOfHeapCommit -0.0047; SectionsMeanVirtualsize -0.0196; VersionInformationSize 0.3377; ImageBase -0.0060; ResourcesNb -0.1190; Machine -0.4100; DllCharacteristics 0.7768; MajorOperatingSystemVersion -0.0021; ImportsNb -0.2005; MinorLinkerVersion -0.3137; ResourcesMaxEntropy -0.0638; LoaderFlags -0.0030; SectionsMinEntropy 1.0732; Characteristics -0.5712; SectionsMeanRawsize -0.0118; SectionsMinVirtualsize -0.0378; SectionsMinRawsize -0.0335; LoadConfigurationSize -0.0165; SectionMaxVirtualsize -0.0212; ExportNb -0.1042; ResourcesMinSize -0.0031; MinorSubsystemVersion 0.1746; ResourcesMeanSize -0.0068; MajorLinkerVersion 0.3460; ResourcesMeanEntropy -0.1925; SizeOfOptionalHeader -0.4094; Subsystem -0.3927; S ...
# y: CategoryList
# 0,0,0,0,0
# Path: /home/hritik/Documents/BirdVision;
#
# Test: None, model=TabularModel(
#   (embeds): ModuleList()
#   (emb_drop): Dropout(p=0.0, inplace=False)
#   (bn_cont): BatchNorm1d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=54, out_features=200, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=200, out_features=100, bias=True)
#     (4): ReLU(inplace=True)
#     (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Linear(in_features=100, out_features=2, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f5f633ce6a8>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/home/hritik/Documents/BirdVision'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): ModuleList()
#   (1): Dropout(p=0.0, inplace=False)
#   (2): BatchNorm1d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): Linear(in_features=54, out_features=200, bias=True)
#   (4): ReLU(inplace=True)
#   (5): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): Linear(in_features=200, out_features=100, bias=True)
#   (7): ReLU(inplace=True)
#   (8): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): Linear(in_features=100, out_features=2, bias=True)
# )], add_time=True, silent=False)

# %%
learn.summary()
# Out:
# TabularModel
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# BatchNorm1d          [54]                 108        True
# ______________________________________________________________________
# Linear               [200]                11,000     True
# ______________________________________________________________________
# ReLU                 [200]                0          False
# ______________________________________________________________________
# BatchNorm1d          [200]                400        True
# ______________________________________________________________________
# Linear               [100]                20,100     True
# ______________________________________________________________________
# ReLU                 [100]                0          False
# ______________________________________________________________________
# BatchNorm1d          [100]                200        True
# ______________________________________________________________________
# Linear               [2]                  202        True
# ______________________________________________________________________
#
# Total params: 32,010
# Total trainable params: 32,010
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.fit_one_cycle(6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.049406</td>
#       <td>0.136059</td>
#       <td>0.987359</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.037578</td>
#       <td>0.058675</td>
#       <td>0.981093</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.032044</td>
#       <td>0.031681</td>
#       <td>0.990945</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.028992</td>
#       <td>0.026686</td>
#       <td>0.991452</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.024910</td>
#       <td>0.023770</td>
#       <td>0.991923</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.028122</td>
#       <td>0.024613</td>
#       <td>0.991090</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
